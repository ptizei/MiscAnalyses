# %%
library(rlang)
# Out:
# Warning message:
# "package 'rlang' was built under R version 3.6.3"

# %%
install.packages(c("coda","mvtnorm","devtools"))
library(devtools)
devtools::install_github("rmcelreath/rethinking",ref="Experimental")
# Out:
# Installing packages into 'C:/Users/ptize/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# also installing the dependencies 'ini', 'fs', 'gh', 'git2r', 'rex', 'xopen', 'brew', 'commonmark', 'usethis', 'cli', 'covr', 'jsonlite', 'memoise', 'rcmdcheck', 'remotes', 'roxygen2', 'rstudioapi', 'rversions', 'sessioninfo', 'withr'
# package 'ini' successfully unpacked and MD5 sums checked
# package 'fs' successfully unpacked and MD5 sums checked
# package 'gh' successfully unpacked and MD5 sums checked
# package 'git2r' successfully unpacked and MD5 sums checked
# package 'rex' successfully unpacked and MD5 sums checked
# package 'xopen' successfully unpacked and MD5 sums checked
# package 'brew' successfully unpacked and MD5 sums checked
# package 'commonmark' successfully unpacked and MD5 sums checked
# package 'usethis' successfully unpacked and MD5 sums checked
# package 'cli' successfully unpacked and MD5 sums checked
# package 'covr' successfully unpacked and MD5 sums checked
# ...

# %%
R.version
# Out:
#                _
# platform       x86_64-w64-mingw32
# arch           x86_64
# os             mingw32
# system         x86_64, mingw32
# status
# major          3
# minor          6.1
# year           2019
# month          07
# day            05
# svn rev        76782
# language       R
# version.string R version 3.6.1 (2019-07-05)
# nickname       Action of the Toes

# %%
package.version(rlang)
# Out:
# Error in package.version(rlang): could not find function "package.version"
# Traceback:

# %%
library(rlang)

# %%
pack
